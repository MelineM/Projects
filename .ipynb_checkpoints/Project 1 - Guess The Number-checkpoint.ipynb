# %% [markdown]
# # Project 1
#
# ## Guess The Number Game
#
# This project is the classic "Guess The Number" game!
#
# Simply run the code in the below cell and follow the instructions!

# %%
def guess_the_number():
    import time
    import datetime
    currentTime = datetime.datetime.now()
    currentTime.hour
    if currentTime.hour < 12:
        print("Good morning! Let's play a game!")
        time.sleep(1)
    elif 12 <= currentTime.hour < 18:
        print("Good afternoon! Let's play a game!")
        time.sleep(1)
    else:
        print("Good evening! Let's play a game!")
        time.sleep(1)
        print("I wonder if you can guess the number I am thinking of...")
        time.sleep(1)
    global name
    name = input("Before we begin, tell me your name. ")
    print("Hi " + name +"!")
    time.sleep(1)
    print("Let's play Guess the Number!")
    time.sleep(2)
    print("First, let me tell you how to play.")
    time.sleep(2)
    print("I will think of a number between 1 & 10 and you will have 3 chances to guess my number.")
    time.sleep(3)

    def ready():
        flag1=0
        import time
        print("Are you ready? ")
        while True:
            choice = input("Yes or no? [Y/N]? : ").lower()
            if choice in ['y', 'n', "yes", "no"]:
                break
        if choice in ['y', "yes"]: 
            print ("Great!")
            return flag1
        else: 
            print("What a shame! Maybe another time! Bye!")
            time.sleep(2)
            print("Thanks for wasting my time. Loser...")
            flag1=1
            return flag1
    flag1=ready()
    if flag1==1:
        return    

    def action():
        global win
        win = 0
        choice = input("So, what's your first guess? ")
        import random
        number = random.randint(1, 10)
        import time
        too_low = "Sorry, your guess is too low! Try again."
        too_high = "Sorry your guess is too high! Try again."
        second_guess = "What's your 2nd guess? "
        final_guess = "What's your final guess? " 
        too_low_one_left = "Sorry your guess is too low! You have one guess left! Use it wisely..."
        too_high_one_left = "Sorry your guess is too high! You have one guess left! Use it wisely..."
        too_low_lost_game = "Sorry your guess is too low! My number is " + str(number) + ". You lost the game!"
        too_high_lost_game = "Sorry your guess is too high! My number is " + str(number) + ". You lost the game!"
        first_guess_win = "You guessed my number on your first try! You win the game!"
        second_guess_win = "You guessed my number on your second try! You win the game!"
        third_guess_win = "You guessed my number on your third try! You win the game!"
        wow = "Wow, you're really not good at this, are you..."
        if int(choice) < number:
            print(too_low)
            choice = input(second_guess)
            if int(choice) < number:
                print(too_low_one_left)
                choice = input(final_guess)
                if int(choice) < number:
                    print(too_low_lost_game)
                    time.sleep(2)
                elif int(choice) > number:
                    print(too_high_lost_game)
                    time.sleep(2)
                elif int(choice) == number:
                    print(third_guess_win)
                    win += 1 
            elif int(choice) > number:
                print(too_high_one_left)
                choice = input(final_guess)
                if int(choice) < number:
                    print(too_low_lost_game)
                    time.sleep(2)
                elif int(choice) > number:
                    print(too_high_lost_game)
                    time.sleep(2)
                elif int(choice) == number:
                    print(third_guess_win)
                    win += 1
            elif int(choice) == number:
                print(second_guess_win)
                win += 1
        elif int(choice) > number:
            print(too_high)
            choice = input(second_guess)
            if int(choice) < number:
                print(too_low_one_left)
                choice = input(final_guess)
                if int(choice) < number:
                    print(too_low_lost_game)
                    time.sleep(2)
                    print(wow)
                elif int(choice) > number:
                    print(too_high_lost_game)
                    time.sleep(2)
                    print(wow)
                elif int(choice) == number:
                    print(third_guess_win)
                    win += 1
            elif int(choice) > number:
                print(too_high_one_left)
                choice = input(final_guess)
                if int(choice) < number:
                    print(too_low_lost_game)
                    time.sleep(2)
                    print(wow)
                elif int(choice) > number:
                    print(too_high_lost_game)
                    time.sleep(2)
                    print(wow)
                elif int(choice) == number:
                    print(third_guess_win)
                    win += 1
            elif int(choice) == number:
                print(second_guess_win)
                win += 1
        elif int(choice) == number:
            print(first_guess_win)
            win += 1
            import time
            time.sleep(3)
            print("Hey, I have a question for you...")
            time.sleep(3)
            print("Are you psychic?")
        if win == 1:
            money = 100
            import time
            time.sleep(3)
            print("So you think you're a good guesser huh?")
            time.sleep(3)
            print("Why don't you put your money where your mouth is?")
            time.sleep(3)
            print("Let's play the same game only this time you need to bet some money.")
            time.sleep(3)
            print("You have 100€ to play with.")
            time.sleep(2)
            bet = input("How much would you like to bet? ")
            if int(bet) >= 75:
                print("Well hello big spender!!")
                print("You bet " + str(bet) + "€. Let's play!")
            elif 25 < int(bet) < 75:
                print("You bet " + str(bet) + "€. Let's play!")
            else:
                print("That's it? Really? OK...")
                print("You bet " + str(bet) + "€. Let's play!")
        else:
            print("GAME OVER")    
        if win == 1:
            choice = input("What's your first guess? ")
            number = random.randint(1, 10)
            won_bet_value = "You've won " + str(bet) +"€. We weren't playing for real money though, were we?"
            won_bet_insisting = "Do I really have to give you the money? "
            too_low_my_number = "Sorry your guess is too low! My number is " + str(number) + ". You lost the game!"
            too_high_my_number = "Sorry your guess is too high! My number is " + str(number) + ". You lost the game!"
            if int(choice) < number:
                print(too_low)
                choice = input(second_guess)
                if int(choice) < number:
                    print(too_low_one_left)
                    choice = input(final_guess)
                    if int(choice) < number:
                        print(too_low_lost_game)
                        money -= int(bet)
                        time.sleep(1)
                        print("You lost " + str(bet) + "€. Now you have " + str(money) + "€ left and I'm " + str(bet) +"€ richer.")
                    elif int(choice) > number:
                        print(too_high_lost_game)
                        money -= int(bet)
                        time.sleep(1)
                        print("You lost " + str(bet) + "€. Now you have " + str(money) + "€ left and I'm " + str(bet) + "€ richer.")
                    elif int(choice) == number:
                        print(third_guess_win)
                        time.sleep(2)
                        print(won_bet_value)
                        while True:
                            insisting = input(won_bet_insisting).lower()
                            if insisting in ['y', 'n', "yes", "no"]:
                                break
                        if insisting in ["y", "yes"]:
                            money += int(bet)
                            print("Fine, now you have " + str(money) + "€ and I'm " + str(bet) + "€ poorer.")
                            time.sleep(1)
                            print("Come back soon so we can play again.")
                            time.sleep(1)
                            print("I need to win my money back!")
                        else:
                            print("That's super kind of you! You still have 100€.")
                            time.sleep(3)
                            print("Wow. What a pushover...")
                elif int(choice) > number:
                    print(too_high_one_left)
                    choice = input(final_guess)
                    if int(choice) < number:
                        print(too_low_my_number)
                        money -= int(bet)
                        time.sleep(1)
                        print("You lost " + str(bet) + "€. Now you have " + str(money) + "€ left and I'm " + str(bet) +"€ richer.")
                    elif int(choice) > number:
                        print(too_high_my_number)
                        money -= int(bet)
                        time.sleep(1)
                        print("You lost " + str(bet) + "€. Now you have " + str(money) + "€ left and I'm " + str(bet) +"€ richer.")
                    elif int(choice) == number:
                        print(third_guess_win)
                        time.sleep(2)
                        print(won_bet_value)
                        while True:
                            insisting = input(won_bet_insisting).lower()
                            if insisting in ['y', 'n', "yes", "no"]:
                                break
                        if insisting in ["y", "yes"]:
                            money += int(bet)
                            print("Fine, now you have " + str(money) + "€ and I'm " + str(bet) + "€ poorer.")
                            time.sleep(1)
                            print("Come back soon so we can play again.")
                            time.sleep(1)
                            print("I need to win my money back!")
                        else:
                            print("That's super kind of you! You still have 100€.")
                            time.sleep(3)
                            print("Wow. What a pushover...")
                elif int(choice) == number:
                    print(second_guess_win)
                    time.sleep(2)
                    print(won_bet_value)
                    while True:
                        insisting = input(won_bet_insisting).lower()
                        if insisting in ['y', 'n', "yes", "no"]:
                            break
                    if insisting in ["y", "yes"]:
                        money += int(bet)
                        print("Fine, now you have " + str(money) + "€ and I'm " + str(bet) + "€ poorer.")
                        time.sleep(1)
                        print("Come back soon so we can play again.")
                        time.sleep(1)
                        print("I need to win my money back!")
                    else:
                        print("That's super kind of you! You still have 100€.")
                        time.sleep(3)
                        print("Wow. What a pushover...")
                    win += 1
            elif int(choice) > number:
                print(too_high)
                choice = input(second_guess)
                if int(choice) < number:
                    print(too_low_one_left)
                    choice = input(final_guess)
                    if int(choice) < number:
                        print(too_low_my_number)
                        money -= int(bet)
                        time.sleep(1)
                        print("You lost " + str(bet) + "€. Now you have " + str(money) + "€ left and I'm " + str(bet) +"€ richer.")
                        print(wow)
                    elif int(choice) > number:
                        print(too_high_my_number)
                        time.sleep(2)
                        print(wow)
                    elif int(choice) == number:
                        print(third_guess_win)
                        time.sleep(2)
                        print(won_bet_value)
                        while True:
                            insisting = input(won_bet_insisting).lower()
                            if insisting in ['y', 'n', "yes", "no"]:
                                break
                        if insisting in ["y", "yes"]:
                            money += int(bet)
                            print("Fine, now you have " + str(money) + "€ and I'm " + str(bet) + "€ poorer.")
                            time.sleep(1)
                            print("Come back soon so we can play again.")
                            time.sleep(1)
                            print("I need to win my money back!")
                        else:
                            print("That's super kind of you! You still have 100€.")
                            time.sleep(3)
                            print("Wow. What a pushover...")
                elif int(choice) > number:
                    print(too_high_one_left)
                    choice = input(final_guess)
                    if int(choice) < number:
                        print(too_low_my_number)
                        money -= int(bet)
                        time.sleep(1)
                        print("You lost " + str(bet) + "€. Now you have " + str(money) + "€ left and I'm " + str(bet) +"€ richer.")
                        print(wow)
                    elif int(choice) > number:
                        print(too_high_my_number)
                        money -= int(bet)
                        time.sleep(1)
                        print("You lost " + str(bet) + "€. Now you have " + str(money) + "€ left and I'm " + str(bet) +"€ richer.")
                        print(wow)
                    elif int(choice) == number:
                        print(third_guess_win)
                        time.sleep(2)
                        print(won_bet_value)
                        while True:
                            insisting = input(won_bet_insisting).lower()
                            if insisting in ['y', 'n', "yes", "no"]:
                                break
                        if insisting in ["y", "yes"]:
                            money += int(bet)
                            print("Fine, now you have " + str(money) + "€ and I'm " + str(bet) + "€ poorer.")
                            time.sleep(1)
                            print("Come back soon so we can play again.")
                            time.sleep(1)
                            print("I need to win my money back!")
                        else:
                            print("That's super kind of you! You still have 100€.")
                            time.sleep(3)
                            print("Wow. What a pushover...")
                elif int(choice) == number:
                    print(second_guess_win)
                    time.sleep(2)
                    print(won_bet_value)
                    while True:
                        insisting = input(won_bet_insisting).lower()
                        if insisting in ['y', 'n', "yes", "no"]:
                            break
                    if insisting in ["y", "yes"]:
                        money += int(bet)
                        print("Fine, now you have " + str(money) + "€ and I'm " + str(bet) + "€ poorer.")
                        time.sleep(1)
                        print("Come back soon so we can play again.")
                        time.sleep(1)
                        print("I need to win my money back!")
                    else:
                        print("That's super kind of you! You still have 100€.")
                        time.sleep(3)
                        print("Wow. What a pushover...")
            elif int(choice) == number:
                print(first_guess_win)
                time.sleep(2)
                print(won_bet_value)
                while True:
                    insisting = input(won_bet_insisting).lower()
                    if insisting in ['y', 'n', "yes", "no"]:
                        break
                if insisting in ["y", "yes"]:
                    money += int(bet)
                    print("Fine, now you have " + str(money) + "€ and I'm " + str(bet) + "€ poorer.")
                    time.sleep(1)
                    print("Come back soon so we can play again.")
                    time.sleep(1)
                    print("I need to win my money back!")
                else:
                    print("That's super kind of you! You still have 100€.")
                    time.sleep(3)
                    print("Wow. What a pushover...")
    action()
               

guess_the_number()
# Out:
# Good afternoon! Let's play a game!
# Before we begin, tell me your name. Meliné
# Hi Meliné!
# Let's play Guess the Number!
# First, let me tell you how to play.
# I will think of a number between 1 & 10 and you will have 3 chances to guess my number.
# Are you ready?
# Yes or no? [Y/N]? : y
# Great!
# So, what's your first guess? 5
# Sorry, your guess is too low! Try again.
# What's your 2nd guess? 8
# Sorry your guess is too high! You have one guess left! Use it wisely...
# What's your final guess? 7
# You guessed my number on your third try! You win the game!
# So you think you're a good guesser huh?
# Why don't you put your money where your mouth is?
# Let's play the same game only this time you need to bet some money.
# You have 100€ to play with.
# How much would you like to bet? 50
# You bet 50€. Let's play!
# What's your first guess? 5
# Sorry, your guess is too low! Try again.
# What's your 2nd guess? 8
# ...
