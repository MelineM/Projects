# %% [markdown]
# # Royal Family Calendar
#
# This is an essential tool for all Royalists who wish to catch a glimpse of their favourite Royals!
#
# Update the dates in the second cell and run the function in order to return a list of all upcoming events in your desired timeframe!
# The function will even save a copy of the events in a csv file for you!

# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
from geotext import GeoText

# %%
lst=[]
for i in range(12):
    lst.append('https://www.royal.uk/future-engagements?text=&mrf=&date%5Bmin%5D%5Bdate%5D=20/01/2020&date%5Bmax%5D%5Bdate%5D=02/02/2020&id=&page='+str(i))
lst
# Out:
# ['https://www.royal.uk/future-engagements?text=&mrf=&date%5Bmin%5D%5Bdate%5D=20/01/2020&date%5Bmax%5D%5Bdate%5D=02/02/2020&id=&page=0',
#  'https://www.royal.uk/future-engagements?text=&mrf=&date%5Bmin%5D%5Bdate%5D=20/01/2020&date%5Bmax%5D%5Bdate%5D=02/02/2020&id=&page=1',
#  'https://www.royal.uk/future-engagements?text=&mrf=&date%5Bmin%5D%5Bdate%5D=20/01/2020&date%5Bmax%5D%5Bdate%5D=02/02/2020&id=&page=2',
#  'https://www.royal.uk/future-engagements?text=&mrf=&date%5Bmin%5D%5Bdate%5D=20/01/2020&date%5Bmax%5D%5Bdate%5D=02/02/2020&id=&page=3',
#  'https://www.royal.uk/future-engagements?text=&mrf=&date%5Bmin%5D%5Bdate%5D=20/01/2020&date%5Bmax%5D%5Bdate%5D=02/02/2020&id=&page=4',
#  'https://www.royal.uk/future-engagements?text=&mrf=&date%5Bmin%5D%5Bdate%5D=20/01/2020&date%5Bmax%5D%5Bdate%5D=02/02/2020&id=&page=5',
#  'https://www.royal.uk/future-engagements?text=&mrf=&date%5Bmin%5D%5Bdate%5D=20/01/2020&date%5Bmax%5D%5Bdate%5D=02/02/2020&id=&page=6',
#  'https://www.royal.uk/future-engagements?text=&mrf=&date%5Bmin%5D%5Bdate%5D=20/01/2020&date%5Bmax%5D%5Bdate%5D=02/02/2020&id=&page=7',
#  'https://www.royal.uk/future-engagements?text=&mrf=&date%5Bmin%5D%5Bdate%5D=20/01/2020&date%5Bmax%5D%5Bdate%5D=02/02/2020&id=&page=8',
#  'https://www.royal.uk/future-engagements?text=&mrf=&date%5Bmin%5D%5Bdate%5D=20/01/2020&date%5Bmax%5D%5Bdate%5D=02/02/2020&id=&page=9',
#  'https://www.royal.uk/future-engagements?text=&mrf=&date%5Bmin%5D%5Bdate%5D=20/01/2020&date%5Bmax%5D%5Bdate%5D=02/02/2020&id=&page=10',
#  'https://www.royal.uk/future-engagements?text=&mrf=&date%5Bmin%5D%5Bdate%5D=20/01/2020&date%5Bmax%5D%5Bdate%5D=02/02/2020&id=&page=11']

# %%
def royal_events(lst):
    colnames = ["Date", "Member of Royal Family", "Event", "Location"]
    df = pd.DataFrame(columns=colnames)
    for url in lst:
        html = requests.get(url).content
        soup = BeautifulSoup(html)
        dates = soup.select("section ul li div span")
        dates = [i.string for i in dates]
        royals = soup.select("li h2")
        royals = [i.string for i in royals]
        events = soup.select("li div p")
        events = [i.string for i in events]

        new_events = []
        for event in events:
            m=re.search(r"(\bwill\b\s*(?:\S+\b\s*(.*?,|\W)){0,})",str(event)).group(0)
            new_events.append(m)
        events2 = [event.strip(",") for event in new_events]
        clean_events = [event.strip("will ") for event in events2]

        locations = []
        for event in events:
            if "," in event:
                event=event.split(", ")
                locations.append(event[-1])
            elif "at" in event:
                event=event.split(" at ")
                locations.append(event[-1])
            elif "in" in event:
                event=event.split(" in ")
                locations.append(event[-1])

        City = []
        for event in events:
            city = GeoText(event)
            City.append(city.cities)
        
        df1 = pd.DataFrame(columns=colnames)
        df1["Date"] = dates
        df1["Member of Royal Family"] = royals
        df1["Event"] = clean_events
        df1["Location"] = City
        df=df.append(df1)
    df = df.reset_index(drop=True)
    df.index = df.index + 1
    df.to_csv('Royal_Events.csv', sep=',')
    return df

royal_events(lst)
# Out:
#                Date                           Member of Royal Family  \
# 1   20 January 2020  The Duke of Cambridge, The Duchess of Cambridge
# 2   20 January 2020                          The Duchess of Cornwall
# 3   21 January 2020                           The Duke of Gloucester
# 4   21 January 2020                               The Princess Royal
# 5   21 January 2020                               The Princess Royal
# 6   22 January 2020                               The Princess Royal
# 7   22 January 2020                          The Duchess of Cornwall
# 8   22 January 2020                          The Duchess of Cornwall
# 9   23 January 2020                               The Princess Royal
# 10  23 January 2020                               The Princess Royal
# 11  23 January 2020                               The Princess Royal
# 12  23 January 2020                               The Princess Royal
# 13  24 January 2020                               The Princess Royal
# 14  27 January 2020                                 The Duke of Kent
# 15  27 January 2020                               The Earl of Wessex
# 16  28 January 2020                               The Princess Royal
# 17  28 January 2020                               The Princess Royal
# 18  28 January 2020                           The Duke of Gloucester
# 19  28 January 2020                        The Duchess of Gloucester
# 20  29 January 2020                               The Princess Royal
# 21  29 January 2020                           The Countess of Wessex
# 22  29 January 2020                           The Countess of Wessex
# 23  30 January 2020                           The Countess of Wessex
#
#                                                 Event  \
# 1   host a reception to mark the UK-Africa Investm...
# 2                              visit Prospect Hospice
# 3                        attend a Luncheon at Savills
# 4   attend the British Equestrian Trade Associatio...
# 5           attend the Annual Court and Livery Dinner
# 6   attend the quarterly meeting of the Court and ...
# 7                            visit the Launer Factory
# 8                         visit Elmhurst Ballet Schoo
# 9   visit the 'Changing Lives through Horses' Prog...
# 10                     attend a Dinner in Perthshire.
# 11  visit the Cafe Neuro Drop-In at St. Mary's Liv...
# 12                visit John Spencer Textiles Limited
# 13                 open the Drumfork Community Centre
# 14  attend the Gold Medal Showcase Reception and C...
# 15  attend the Holocaust Memorial Event at Norden ...
# 16                            open Eleanor Rosa House
# 17  attend the IFR Annual Awards Dinner at the Gro...
# 18  attend a Reception to mark World Leprosy Day a...
# 19  attend presentations by the Army Families Fede...
# 20                         visit Simon Carter Limited
# 21                     visit the Univeristy of Surrey
# 22                     hold a Dinner at Bagshot Park.
# 23  NOT NOW attend the International Day of the Gi...
#
#                         Location
# 1                       [Summit]
# 2                      [Swindon]
# 3                       [London]
# 4                   [Birmingham]
# 5                       [London]
# 6                       [London]
# 7                      [Walsall]
# 8                   [Birmingham]
# 9                        [Wigan]
# 10                            []
# 11                        [Mary]
# 12                     [Burnley]
# 13                            []
# 14                      [London]
# 15                  [Maidenhead]
# 16  [University, London, London]
# 17                      [London]
# 18                      [London]
# 19           [Whitehall, London]
# 20                      [London]
# 21           [Surrey, Guildford]
# 22                            []
# 23           [Edinburgh, London]
